# %% [markdown]
# <a href="https://colab.research.google.com/github/hend-22/-IT326-Project/blob/main/Reports/Phase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Daily Stress Level Prediction Using Wearable and Lifestyle Data

# %% [markdown]
# ## Project Goal
# The goal of this project is to apply classification and clustering techniques to wearable and lifestyle data. Classification will be used to predict the Daily_Stress_Level as Low, Medium, or High, while clustering will be used to identify groups with similar characteristics.

# %% [markdown]
# ## Dataset Source
#
# Source: Kaggle
# URL: https://www.kaggle.com/datasets/itzzomkar/wearable-tech-sleep-quality-and-stress/data

# %% [markdown]
# ## Dataset Description

# %% [markdown]
# **Number of instances:** 10000
#
# **Number of attributes:** 16

# %%
import pandas as pd

df = pd.read_csv('/content/Raw_Dataset.csv')
df.shape
# Out:
# (10000, 16)

# %% [markdown]
# **Features :**
#
# Data types and numbers of the attirubtes.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   User_ID                  10000 non-null  object
#  1   Age                      10000 non-null  int64
#  2   Gender                   10000 non-null  object
#  3   Physical_Activity_Level  10000 non-null  object
#  4   Diet_Type                10000 non-null  object
#  5   BMI                      9790 non-null   float64
#  6   Caffeine_Intake_mg       9794 non-null   float64
#  7   Water_Intake_liters      10000 non-null  float64
#  8   Screen_Time_Hours        10000 non-null  float64
#  9   Daily_Steps              10000 non-null  int64
#  10  Calories_Burned          10000 non-null  int64
#  11  Resting_Heart_Rate       9781 non-null   float64
#  12  Daily_Sleep_Hours        9810 non-null   float64
#  13  Deep_Sleep_Hours         10000 non-null  float64
# ...

# %% [markdown]
# **Class attribute:** Daily_Stress_Level
#
#  **Class values:**
#   - Low: 5,789
#   - Medium: 3,786
#   - High: 425

# %%
df['Daily_Stress_Level'].value_counts()
# Out:
# Daily_Stress_Level
# Low       5789
# Medium    3786
# High       425
# Name: count, dtype: int64

# %% [markdown]
# **Dataset Sample**
#
# To print a small sample of the raw dataset to show how the data looks.

# %%
df.head()
# Out:
#   User_ID  Age  Gender Physical_Activity_Level  Diet_Type   BMI  \
# 0  U00001   56  Female                     Low    Healthy  25.1
# 1  U00002   69    Male                     Low    Average  25.8
# 2  U00003   46    Male                     Low    Average  24.0
# 3  U00004   32  Female                  Medium    Healthy  25.5
# 4  U00005   60    Male                  Medium  Unhealthy   NaN
#
#    Caffeine_Intake_mg  Water_Intake_liters  Screen_Time_Hours  Daily_Steps  \
# 0                99.0                  1.6                3.9         4731
# 1               104.0                  2.2                3.9         4440
# 2               188.0                  1.4                5.5         5023
# 3               124.0                  3.1                9.8         6082
# 4                 0.0                  2.4                5.3         7285
#
#    Calories_Burned  Resting_Heart_Rate  Daily_Sleep_Hours  Deep_Sleep_Hours  \
# ...

# %% [markdown]
# # Dataset Summary
# - Number of instances: 10,000
# - Number of attributes: 16
# - Data types: 8 float, 3 integer, and 5 object attributes
# - Class attribute: Daily_Stress_Level
# - Class values:
#   - Low: 5,789
#   - Medium: 3,786
#   - High: 425
