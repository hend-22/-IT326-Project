# %% [markdown]
# <a href="https://colab.research.google.com/github/hend-22/-IT326-Project/blob/main/Phase2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/hend-22/-IT326-Project.git
# Out:
# Cloning into '-IT326-Project'...
# remote: Enumerating objects: 94, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 94 (delta 34), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (94/94), 1.98 MiB | 8.41 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
# !ls -la ./-IT326-Project
# Out:
# total 92
# drwxr-xr-x 5 root root  4096 Sep 25 13:16 .
# drwxr-xr-x 1 root root  4096 Sep 25 13:16 ..
# drwxr-xr-x 2 root root  4096 Sep 25 13:16 Dataset
# drwxr-xr-x 8 root root  4096 Sep 25 13:16 .git
# -rw-r--r-- 1 root root 65679 Sep 25 13:16 Phase2.ipynb
# -rw-r--r-- 1 root root  1788 Sep 25 13:16 README.md
# drwxr-xr-x 2 root root  4096 Sep 25 13:16 Reports

# %%
# !ls -la ./-IT326-Project/Dataset
# Out:
# total 3192
# drwxr-xr-x 2 root root    4096 Sep 25 13:16 .
# drwxr-xr-x 5 root root    4096 Sep 25 13:16 ..
# -rw-r--r-- 1 root root  824162 Sep 25 13:16 Preprocessed_dataset.csv
# -rw-r--r-- 1 root root  819722 Sep 25 13:16 Raw_Dataset.csv
# -rw-r--r-- 1 root root 1606101 Sep 25 13:16 Reasearch_Paper_Stress_Detection.pdf

# %%
import pandas as pd

file_path = "./-IT326-Project/Dataset/Raw_Dataset.csv"
df = pd.read_csv(file_path)

df.head()
# Out:
#   User_ID  Age  Gender Physical_Activity_Level  Diet_Type   BMI  \
# 0  U00001   56  Female                     Low    Healthy  25.1
# 1  U00002   69    Male                     Low    Average  25.8
# 2  U00003   46    Male                     Low    Average  24.0
# 3  U00004   32  Female                  Medium    Healthy  25.5
# 4  U00005   60    Male                  Medium  Unhealthy   NaN
#
#    Caffeine_Intake_mg  Water_Intake_liters  Screen_Time_Hours  Daily_Steps  \
# 0                99.0                  1.6                3.9         4731
# 1               104.0                  2.2                3.9         4440
# 2               188.0                  1.4                5.5         5023
# 3               124.0                  3.1                9.8         6082
# 4                 0.0                  2.4                5.3         7285
#
#    Calories_Burned  Resting_Heart_Rate  Daily_Sleep_Hours  Deep_Sleep_Hours  \
# ...

# %%
# Missing-value analysis
missing_count = df.isnull().sum()
missing_percentage = (df.isnull().sum() / len(df)) * 100

missing_analysis = pd.DataFrame({
    'Missing Values': missing_count,
    'Percentage (%)': missing_percentage
})

missing_analysis
# Out:
#                          Missing Values  Percentage (%)
# User_ID                               0            0.00
# Age                                   0            0.00
# Gender                                0            0.00
# Physical_Activity_Level               0            0.00
# Diet_Type                             0            0.00
# BMI                                 210            2.10
# Caffeine_Intake_mg                  206            2.06
# Water_Intake_liters                   0            0.00
# Screen_Time_Hours                     0            0.00
# Daily_Steps                           0            0.00
# Calories_Burned                       0            0.00
# Resting_Heart_Rate                  219            2.19
# Daily_Sleep_Hours                   190            1.90
# Deep_Sleep_Hours                      0            0.00
# Sleep_Quality_Score                   0            0.00
# Daily_Stress_Level                    0            0.00

# %%
# Examine columns with missing values
missing_columns = df.columns[df.isnull().any()]

df[missing_columns].describe()
# Out:
#                BMI  Caffeine_Intake_mg  Resting_Heart_Rate  Daily_Sleep_Hours
# count  9790.000000         9794.000000         9781.000000        9810.000000
# mean     25.087406          207.365224           66.944177           6.957951
# std       3.905276          137.681368            8.450527           0.907726
# min      17.500000            0.000000           50.000000           3.500000
# 25%      22.300000          100.000000           61.000000           6.300000
# 50%      25.100000          201.000000           67.000000           7.000000
# 75%      27.800000          303.000000           73.000000           7.600000
# max      38.000000          730.000000           95.000000          10.900000

# %%
# Check skewness of columns with missing values
df[missing_columns].skew()
# Out:
# BMI                   0.151747
# Caffeine_Intake_mg    0.338752
# Resting_Heart_Rate   -0.022946
# Daily_Sleep_Hours     0.030105
# dtype: float64

# %%
# Preprocessing Technique #1: Mean Imputation

df_preprocessed = df.copy()

for column in missing_columns:
    df_preprocessed[column] = df_preprocessed[column].fillna(
        df_preprocessed[column].mean()
    )

# Check missing values after preprocessing
df_preprocessed[missing_columns].isnull().sum()
# Out:
# BMI                   0
# Caffeine_Intake_mg    0
# Resting_Heart_Rate    0
# Daily_Sleep_Hours     0
# dtype: int64

# %%
# Compare missing values before and after preprocessing

comparison = pd.DataFrame({
    'Before': df[missing_columns].isnull().sum(),
    'After': df_preprocessed[missing_columns].isnull().sum()
})

comparison
# Out:
#                     Before  After
# BMI                    210      0
# Caffeine_Intake_mg     206      0
# Resting_Heart_Rate     219      0
# Daily_Sleep_Hours      190      0

# %%
# Remove the user identifier
df_preprocessed = df_preprocessed.drop(columns=['User_ID'])

# %%
# Identify numerical attributes before converting categorical attributes
numeric_columns = df_preprocessed.select_dtypes(include='number').columns

# %%
# perform normalization using minmax
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_preprocessed[numeric_columns] = scaler.fit_transform(df_preprocessed[numeric_columns])

# %%
df_preprocessed.head()
# Out:
#         Age  Gender Physical_Activity_Level  Diet_Type       BMI  \
# 0  0.745098  Female                     Low    Healthy  0.370732
# 1  1.000000    Male                     Low    Average  0.404878
# 2  0.549020    Male                     Low    Average  0.317073
# 3  0.274510  Female                  Medium    Healthy  0.390244
# 4  0.823529    Male                  Medium  Unhealthy  0.370117
#
#    Caffeine_Intake_mg  Water_Intake_liters  Screen_Time_Hours  Daily_Steps  \
# 0            0.135616             0.244444           0.158333     0.166184
# 1            0.142466             0.377778           0.158333     0.153223
# 2            0.257534             0.200000           0.291667     0.179190
# 3            0.169863             0.577778           0.650000     0.226360
# 4            0.000000             0.422222           0.275000     0.279943
#
#    Calories_Burned  Resting_Heart_Rate  Daily_Sleep_Hours  Deep_Sleep_Hours  \
# ...

# %%
categorical_columns = ['Gender', 'Physical_Activity_Level', 'Diet_Type']

df_preprocessed = pd.get_dummies(df_preprocessed,columns=categorical_columns, dtype=int)

# %%
# Save the preprocessed dataset separately
output_path = "./-IT326-Project/Dataset/Preprocessed_dataset.csv"

df_preprocessed.to_csv(output_path, index=False)

print("Preprocessed dataset saved successfully.")
# Out:
# Preprocessed dataset saved successfully.

# %%
# !ls -la ./-IT326-Project/Dataset
# Out:
# total 3192
# drwxr-xr-x 2 root root    4096 Sep 25 13:16 .
# drwxr-xr-x 5 root root    4096 Sep 25 13:16 ..
# -rw-r--r-- 1 root root  824162 Sep 25 13:16 Preprocessed_dataset.csv
# -rw-r--r-- 1 root root  819722 Sep 25 13:16 Raw_Dataset.csv
# -rw-r--r-- 1 root root 1606101 Sep 25 13:16 Reasearch_Paper_Stress_Detection.pdf

# %% [markdown]
# The dataset was analyzed for missing values by calculating the number and percentage of missing values in each attribute.
